# %% [markdown]
# # 動作確認
# Pythonのプログラムで「 2 + 3 」を計算させてみます。
#
# 下のセルの左はしにある [ 　 ] にカーソルをあわせるど出てくる ![2022-03-20_11-48-33.png](data:image/png;base64,...) アイコンをクリックしてください。
#
# 「Googleへのログインが必要」と出たら、自分のGoogleアカウントでログインします。
#
# 「警告: このノートブックは Google が作成したものではありません。」が出たら、「このまま実行」をクリックします。
#
# 少し待って、セルの下に「 5 」と出てくれば成功です。
# プログラムが動きました。
# おめでとう！

# %%
print( 2 + 3 )

# %% [markdown]
# # Google Colab とは
#
# Python はプログラミング言語です。
#
# Windows、Mac、Linuxなど、色々な環境にインストールしてプログラム開発ができます。
#
# Pythonのプログラム開発を、Webブラウザ上で出来るようにしたのが、Jupyter Notebook（ジュピターノートブック）です。Webサーバーにインストールして動かします。
#
# Jupyter NotebookにGoogleが開発した機械学習ライブラリTensorFlow（テンサーフロー）などを加え、すぐにWebブラウザから使える状態で公開しているサービスが、Google Colaboratry（略称 Colab）です。
#
# Colaboratory よくある質問 (https://research.google.com/colaboratory/faq.html?hl=ja) もみてください。
#
# Jupyter Notebookは、以前は「IPython Notebook」という名前だったため、ファイル拡張子は ipynb です。

# %% [markdown]
# ## コードとテキスト
# Colab では、コードとテキストを入力することができます。
#
# ### テキスト
#
# テキストは、説明やメモ書きを書くところです。
# ココは、テキストです。
#
# Markdown という書式で、見出しを付けたり、リンクを付けたりできます。Markdown は、プログラミング業界では、ドキュメントを書くのに使われたりします。
#
# Markdown については、こちらも参照してください。
# https://ja.wikipedia.org/wiki/Markdown
#
# 画面上にある「＋テキスト」をクリックして、テキストを追加してみましょう。
#
# ### コード
#
# コードは、Pythonのプログラムを書くところです。
# 下の「セル」はコードです。
#
# コードに書かれたコードは、実際に動きます。下のセルの左側にある [  ] にカーソルをあわせ、▶（三角のマーク）のアイコンをクリックすると、プログラムが動き出します。
#
# 警告が出たら、「このまま実行」をクリックしてください。
#
# プログラムは、Googleの用意したサーバーの中で動き、結果だけがWebブラウザに表示されます。

# %%
print("Hello,World!")

# %% [markdown]
# ## エディタ設定
# 右のほうにある歯車アイコン![haguruma.png](data:image/png;base64,...)でエディタの設定をしましょう。
#
# インデント幅を4に、「インデントガイドの表示」をチェックしておくと良いです。
#
# 「行番号を表示」は、チェックしてもしなくても、お好きなように。

# %% [markdown]
# ## キーボードの使い方
#
# | キー操作 | 動作 |
# |:--:|:--|
# | [shift]+[↑] | 行選択 |
# | [shift]+[↓] | 行選択 |
# | [shift]+[←] | 文字選択 |
# | [shift]+[→] | 文字選択 |
# | [ ctrl ]+[ c ] | コピー |
