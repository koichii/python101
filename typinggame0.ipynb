# %% [markdown]
# # タイピング ゲーム（素材）
#
# 表示された単語を正しく入力して、その早さを競います。
# 以下の素材を組み合わせて、ゲームをつくりましょう。
#
# ## Scratch版
# https://scratch.mit.edu/projects/659945072

# %%
Q = "abc"
print(Q, " と いれて")
A = input()
if Q == A:
    print("せいかい")
else:
    print("まちがい")

# %%
mondai = ["news", "hello", "girl", "chair", "desk"] 
i = 0
while i < len(mondai):
    print(mondai[i])
    i = i + 1

# %%
import time
print(time.time())
print(time.time())
