# %% [markdown]
# # Glowscript VPython の説明
# Glowscript VPython で使えるオブジェクトや関数を説明します。
#
# ## 3Dオブジェクト
# Glowscript VPython で使える3Dオブジェクトの一覧です。

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/e7e61304e4", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/e7e61304e4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## pos（ポジション）
# 位置（いち）は、pos = vec(x,y,z)で指定します。

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/0fa52c781c", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/0fa52c781c"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## color（カラー）
# カラーは、あらかじめ10色が用意してあります。
# red, yellow, black, green, orange, white, blue, cyan, purple, magenta
#
# ```python
#     obj.color = color.色名
# ```
#
# ### color（カラー）
# カラーは、3通りの指定方法があります。
# ```python
#     obj.color = vec(R,G,B) # R=赤,G=緑,B=青。それぞれ 0～1のあいだ。
#     obj.color = color.色名 # 次のいずれか red, yellow, black, green, orange, white, blue, cyan, purple, magenta
#     obj.color = color.hsv_to_rgb(vec(H,S,V)) # H=いろ,S=あざやかさ,V=あかるさ。それぞれ 0～1のあいだ。（Scratchの色指定は0～100）
# ```
#
# ### opacity（オパシティ）不透明度（ふとうめいど）
# ```python
#     obj.opacity = 0.5 # 0～1のあいだの数。0は見えない。1はすけて見えない。
# ```

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/66c157783e", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/66c157783e"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### size（サイズ）
# サイズ（大きさ）は、posと同じように、vec(x,y,z)で指定します。
#
# x=横はば, y=高さ, z=奥行きです。
# ```python
#     obj.size = vec(50,30,50) # サイズ=vec(x,y,z)
# ```

# %% [markdown]
# ## 回転
# オブジェクトの中にある関数を、格好よく「メソッド」とよびます。
#
# box オブジェクトには、 rotate（ローテイト） というメソッドがあります。
# オブジェクトを回転（かいてん）します。
# ```python
#     obj.rotate(angle=a, # まわす角度をラジアンで指定。1回転は pi * 2
#                 axis=vec(x, y, z),  # 回転軸の方向
#                 origin=vec(x, y, z))# 回転軸の原点
# ```
# アニメーションする時は、sleep(スリープ)でプログラムを一時停止します。
# ```python
#     sleep(0.02) # 次の描画まで0.02秒停止する
# ```
# sleepのかわりにrateで、フレームレートを指定しても同じです。
# ```python
#     rate(50) # 1秒間に50フレーム描画する
# ```

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/330ee3a31d", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/330ee3a31d"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
