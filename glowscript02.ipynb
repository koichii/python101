# %% [markdown]
# # Glowscript VPython デモサンプル
# Glowscript VPython でこんなことができます。

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/44b7a560b1", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/44b7a560b1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/122ede451f", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/122ede451f"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/c0aaca3a08", width="100%", height="400")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://trinket.io/embed/glowscript/c0aaca3a08"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/e9c3ca4607", width="100%", height="550")
# Out:
#         <iframe
#             width="100%"
#             height="550"
#             src="https://trinket.io/embed/glowscript/e9c3ca4607"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/eb2d3503b2", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/eb2d3503b2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/58e25a3590", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/58e25a3590"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/44d963b1e0", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/44d963b1e0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/7f4e0e6063", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/7f4e0e6063"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/bbd98e1ccc", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/bbd98e1ccc"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/02a9e5d6d2", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/02a9e5d6d2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.IFrame(src="https://trinket.io/embed/glowscript/741fdd4ee0", width="100%", height="500")
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="https://trinket.io/embed/glowscript/741fdd4ee0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
